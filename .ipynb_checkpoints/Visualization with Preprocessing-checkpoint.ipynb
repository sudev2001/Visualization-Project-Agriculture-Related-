# %% [markdown]
# ### Importing the needed libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read the DataFrame

# %%
df = pd.read_csv('Datasets/project.csv')
df
# Out:
#       Unnamed: 0 State Name District Name Market Name Variety    Group  \
# 0              1     Punjab       Fazilka      Abohar   Other  Cereals
# 1              2     Punjab       Fazilka      Abohar   Other  Cereals
# 2              3     Punjab       Fazilka      Abohar   Other  Cereals
# 3              4     Punjab       Fazilka      Abohar   Other  Cereals
# 4              5     Punjab       Fazilka      Abohar   Other  Cereals
# ...          ...        ...           ...         ...     ...      ...
# 5662        5663     Punjab      Ferozpur        Zira   Other  Cereals
# 5663        5664     Punjab      Ferozpur        Zira   Other  Cereals
# 5664        5665     Punjab      Ferozpur        Zira   Other  Cereals
# 5665        5666     Punjab      Ferozpur        Zira   Other  Cereals
# 5666        5667     Punjab      Ferozpur        Zira   Other  Cereals
#
#      Arrivals (Tonnes)  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5667 entries, 0 to 5666
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 5667 non-null   int64
#  1   State Name                 5667 non-null   object
#  2   District Name              5667 non-null   object
#  3   Market Name                5667 non-null   object
#  4   Variety                    5667 non-null   object
#  5   Group                      5667 non-null   object
#  6   Arrivals (Tonnes)          5659 non-null   object
#  7   Min Price (Rs./Quintal)    5667 non-null   float64
#  8   Max Price (Rs./Quintal)    5667 non-null   int64
#  9   Modal Price (Rs./Quintal)  5667 non-null   int64
#  10  Reported Date              5667 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 487.1+ KB

# %%
df['Reported Date'] = pd.to_datetime(df['Reported Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5667 entries, 0 to 5666
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 5667 non-null   int64
#  1   State Name                 5667 non-null   object
#  2   District Name              5667 non-null   object
#  3   Market Name                5667 non-null   object
#  4   Variety                    5667 non-null   object
#  5   Group                      5667 non-null   object
#  6   Arrivals (Tonnes)          5659 non-null   object
#  7   Min Price (Rs./Quintal)    5667 non-null   float64
#  8   Max Price (Rs./Quintal)    5667 non-null   int64
#  9   Modal Price (Rs./Quintal)  5667 non-null   int64
#  10  Reported Date              5667 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(3), object(6)
# memory usage: 487.1+ KB
